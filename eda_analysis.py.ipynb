# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('preprocessed_crop_data.csv')

# %%
import os

# %%
os.makedirs('plots', exist_ok=True)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Crop', data=df)
plt.title("Crop Distribution")
plt.savefig('plots/crop_distribution.png')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.savefig('plots/correlation_matrix.png')

# %%
print(df.columns)
# Out:
# Index(['N', 'P', 'K', 'Temperature', 'Humidity', 'pH', 'Rainfall', 'Latitude',
#        'Longitude', 'Crop'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
print(df.columns)
# Out:
# Index(['n', 'p', 'k', 'temperature', 'humidity', 'ph', 'rainfall', 'latitude',
#        'longitude', 'crop'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df[['n', 'p', 'k', 'temperature', 'humidity', 'ph', 'crop']], hue='crop')
plt.savefig('plots/features_vs_crop.png')

# %%
print(df.columns.tolist())
# Out:
# ['n', 'p', 'k', 'temperature', 'humidity', 'ph', 'rainfall', 'latitude', 'longitude', 'crop']
